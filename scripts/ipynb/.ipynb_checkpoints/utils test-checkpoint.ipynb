# %%
import cv2
import matplotlib.pyplot as plt
import utils

# %matplotlib inline

# %% [markdown]
# # square_crop

# %% [markdown]
# ### Load original image

# %%
im = cv2.imread('jake.png')
rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)

# %%
rgb.shape
# Out:
# (258, 314, 3)

# %% [markdown]
# ### Hard crop

# %%
plt.imshow(rgb[40:190,40:90])

# %% [markdown]
# ### Square crop (no reshape)

# %%
crop = utils.square_crop(rgb, 224, 40, 40, 50, 150)
plt.imshow(crop)

# %% [markdown]
# ### Hard crop

# %%
plt.imshow(rgb[40:140,40:240])

# %% [markdown]
# ### Square crop (no reshape)

# %%
crop = utils.square_crop(rgb, 224, 40, 40, 200, 100)
plt.imshow(crop)

# %% [markdown]
# # Data loading

# %%
import sys
sys.path.append('/Users/eric/skool/thesis/code/detect-relationships/data/vrd')

init_path = '/Users/eric/code/tensorflow-vgg'



which_net = 'objnet'
output_size = 100


batch_size = 10
meta_epochs = 20

obj_list  = 'data/vrd/objectListN.mat'
rel_list  = 'data/vrd/predicate.mat'
train_mat = 'data/vrd/annotation_train.mat'
test_mat  = 'data/vrd/annotation_test.mat'

data_batcher = load_data_batcher(train_mat, obj_list, rel_list, 
                                 batch_size, meta_epochs, which_net)
