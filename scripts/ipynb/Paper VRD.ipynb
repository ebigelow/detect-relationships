# %%
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# Out:
# The directory '/Users/eric/Library/Caches/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#   Downloading https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master (14.2MB)
#     100% |████████████████████████████████| 14.2MB 39kB/s
#   Requirement already satisfied (use --upgrade to upgrade): jupyter-contrib-nbextensions==0.2.3 from https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master in /usr/local/lib/python2.7/site-packages
# Requirement already satisfied: ipython_genutils in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: jupyter_contrib_core>=0.3 in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: jupyter_core in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.0.5 in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: jupyter_latex_envs>=1.3.4 in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: jupyter_nbextensions_configurator in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: nbconvert in /Library/Python/2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: notebook>=4.0 in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: psutil>=2.2.1 in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: tornado in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: traitlets in /usr/local/lib/python2.7/site-packages (from jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/site-packages (from jupyter_contrib_core>=0.3->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python2.7/site-packages (from nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: pygments in /usr/local/lib/python2.7/site-packages (from nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: mistune!=0.6 in /usr/local/lib/python2.7/site-packages (from nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python2.7/site-packages (from nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python2.7/site-packages (from nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: ipykernel in /usr/local/lib/python2.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python2.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /Library/Python/2.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: singledispatch in /Library/Python/2.7/site-packages (from tornado->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: certifi in /usr/local/lib/python2.7/site-packages (from tornado->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: backports_abc>=0.4 in /usr/local/lib/python2.7/site-packages (from tornado->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: decorator in /usr/local/lib/python2.7/site-packages (from traitlets->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: enum34; python_version == "2.7" in /usr/local/lib/python2.7/site-packages (from traitlets->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: six in /usr/local/lib/python2.7/site-packages/six-1.10.0-py2.7.egg (from traitlets->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: configparser>=3.5; python_version == "2.7" in /usr/local/lib/python2.7/site-packages (from entrypoints->nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.0 in /Library/Python/2.7/site-packages (from nbformat->nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: MarkupSafe in /Library/Python/2.7/site-packages (from jinja2->nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python2.7/site-packages (from ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python2.7/site-packages (from jupyter-client->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: ptyprocess in /Library/Python/2.7/site-packages (from terminado>=0.3.3; sys_platform != "win32"->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: functools32; python_version == "2.7" in /Library/Python/2.7/site-packages (from jsonschema!=2.5.0,>=2.0->nbformat->nbconvert->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: backports.shutil-get-terminal-size; python_version == "2.7" in /usr/local/lib/python2.7/site-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Library/Python/2.7/site-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python2.7/site-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: pathlib2; python_version == "2.7" or python_version == "3.3" in /Library/Python/2.7/site-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.3 in /usr/local/lib/python2.7/site-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: pickleshare in /usr/local/lib/python2.7/site-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: simplegeneric>0.8 in /Library/Python/2.7/site-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python2.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.3->ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter-contrib-nbextensions==0.2.3)

# %%
# !jupyter contrib nbextension install --user
# !jupyter nbextensions_configurator enable --user
# Out:
# jupyter: 'contrib' is not a Jupyter command
# jupyter: 'nbextensions_configurator' is not a Jupyter command

# %%
# !pwd
# Out:
# /Users/eric/code/detect-relationships

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import loadmat, mat_to_triplets

# %%
# Load data
obj_mat   = 'data/vrd/objectListN.mat'
rel_mat   = 'data/vrd/predicate.mat'
train_mat = 'data/vrd/annotation_train.mat'
test_mat = 'data/vrd/annotation_test.mat'

obj_dict = {r:i for i,r in enumerate(loadmat(obj_mat)['objectListN'])}
rel_dict = {r:i for i,r in enumerate(loadmat(rel_mat)['predicate'])}
word2idx = {'obj':obj_dict, 'rel':rel_dict}

obj_dict2 = {i:r for i,r in enumerate(loadmat(obj_mat)['objectListN'])}
rel_dict2 = {i:r for i,r in enumerate(loadmat(rel_mat)['predicate'])}
idx2word = {'obj':obj_dict2, 'rel':rel_dict2}

mat_train = loadmat(train_mat)['annotation_train']
D_train   = mat_to_triplets(mat_train, word2idx)

mat_test = loadmat(test_mat)['annotation_test']
D_test   = mat_to_triplets(mat_test, word2idx)

# %%
R_train = [d[0] for d in D_train]
R_test  = [d[0] for d in D_test]

# %%
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['figure.figsize'] = [6,6]

i,j,k = zip(*R_train)

plt.subplot(311, title='subj')
plt.hist(i, bins=100)
plt.subplot(312, title='obj')
plt.hist(j, bins=100)
plt.subplot(313, title='verb')
plt.hist(k, bins=70)

plt.tight_layout(); plt.show()

# %%
plt.rcParams['figure.figsize'] = [7,2.5]

i,j,k = zip(*(R_test + R_train))

n_i,_,_ = plt.hist(i, bins=100)
n_j,_,_ = plt.hist(j, bins=100)
n_k,_,_ = plt.hist(k, bins=70)

n_i = sorted([sum(i_) for i_ in zip(n_i,n_j)], reverse=True)
n_k = sorted(n_k, reverse=True)

plt.subplot(121, title='Objects')
plt.bar(range(100), n_i)
plt.subplot(122, title='Predicates')
plt.bar(range(70), n_k)

plt.tight_layout(); plt.show()

# %%
# %qtconsole

# %%
for q in [1, 5, 10, 20]:
    print 'Top {}% Subjects: {}'.format(q, sum(n_i[:q]) / sum(n_i))
# Out:
# Top 1% Subjects: 0.411958491188
# Top 5% Subjects: 0.556580464503
# Top 10% Subjects: 0.638346236205
# Top 20% Subjects: 0.739779278537

# %%
for q in [1, 5, 10, 20]:
    print 'Top {}% Objects: {}'.format(q, sum(n_j[:q]) / sum(n_i))
# Out:
# Top 1% Objects: 0.168374238182
# Top 5% Objects: 0.364783396475
# Top 10% Objects: 0.500411793774
# Top 20% Objects: 0.652676659529

# %%
for q in [1, 5, 10, 20]:
    print 'Top {}% Predicates: {}'.format(q, sum(n_k[:q]) / sum(n_i))
# Out:
# Top 1% Predicates: 0.168440125185
# Top 5% Predicates: 0.545379673859
# Top 10% Predicates: 0.78886509636
# Top 20% Predicates: 0.941129962115

# %% [markdown]
# # Testing Data

# %%
i,j,k = zip(*R_test)

plt.subplot(311, title='subj')
sorted(n_i), range(100), _ = plt.hist(i, range=(0,100), bins=100)
#n_i, b_i, _ = plt.hist(i, range=(0,100), bins=100)

plt.subplot(312, title='obj')
sorted(n_j), range(100), _ = plt.hist(i, range=(0,100), bins=100);
plt.bar()
#n_j, b_j, _ = plt.hist(j, range=(0,100), bins=100)

plt.subplot(313, title='verb')
sorted(n_k), range(70), _ = plt.hist(i, range=(0,70), bins=70)
#n_k, b_k, _ = plt.hist(k, range=(0,70), bins=70)

plt.tight_layout(); plt.show()

# %%
n_i = sorted(n_i, reverse=True)
n_j = sorted(n_j, reverse=True)
n_k = sorted(n_k, reverse=True)

# %%
i_test,j_test,k_test = zip(*R_test)
n_i_test, b_i_test, _ = plt.hist(i_test, range=(0,100), bins=100)
n_j_test, b_j_test, _ = plt.hist(j_test, range=(0,100), bins=100)
n_k_test, b_k_test, _ = plt.hist(k_test, range=(0,70), bins=70)

i_train,j_train,k_train = zip(*R_train)
n_i_train, b_i_train, _ = plt.hist(i_train, range=(0,100), bins=100)
n_j_train, b_j_train, _ = plt.hist(j_train, range=(0,100), bins=100)
n_k_train, b_k_train, _ = plt.hist(k_train, range=(0,70), bins=70)



n_i = zip(*sorted(zip(n_i_train, n_i_test), key=lambda x: -x[0]))[1]
n_j = zip(*sorted(zip(n_j_train, n_j_test), key=lambda x: -x[0]))[1]
n_k = zip(*sorted(zip(n_k_train, n_k_test), key=lambda x: -x[0]))[1]

print '\n'
for q in [1, 5, 10, 20]:
    print 'Top {}% Subjects: {}'.format(q, sum(n_i[:q]) / sum(n_i))

print '\n'
for q in [1, 5, 10, 20]:
    print 'Top {}% Objects: {}'.format(q, sum(n_j[:q]) / sum(n_i))
    
print '\n'
for q in [1, 5, 10, 20]:
    print 'Top {}% Predicates: {}'.format(q, sum(n_k[:q]) / sum(n_i))
    
    
    
# TODO: how to do confusion matrix of ranked guesses???
# +1 for each in top [1,5,10,20]
# OR scaled number of points by rank
# Out:
# Top 1% Subjects: 0.399319193506
# Top 5% Subjects: 0.545299816706
# Top 10% Subjects: 0.615475255302
# Top 20% Subjects: 0.720738413197
#
#
# Top 1% Objects: 0.153574234093
# Top 5% Objects: 0.342759884787
# Top 10% Objects: 0.486122021472
# Top 20% Objects: 0.63092432574
#
#
# Top 1% Predicates: 0.18133019115
# Top 5% Predicates: 0.560617962817
# Top 10% Predicates: 0.806231997905
# Top 20% Predicates: 0.93977481016

# %%
predictions
# Out:
# (0.0, 1.0, 9.0, 3.0, 2.0, 10.0, 14.0, 15.0, 18.0, 23.0)

# %%
predictions
# Out:
# (0.0, 1.0, 3.0, 2.0, 10.0, 9.0, 14.0, 15.0, 18.0, 23.0)

# %%
# CONFUSION MATRIX 1:
#   +1 for each in top  q = [1,5,10,20]

q = 15
predictions = zip(*sorted(zip(n_k_train, b_k_train), key=lambda x: -x[0]))[1][:q]

plot_matrix = np.vstack([[(1 if k in predictions else 0) for k in range(70)] for _ in range(70)])
plt.pcolor(plot_matrix, cmap='gray'); plt.show()
plt.ylabel('ground truth')
plt.xlabel('prediction')

# %%
from collections import Counter
d = dict(Counter(k_train))

# %%
# CONFUSION 2:
#    scaled number of points by rank

q = 70
predictions = zip(*sorted(zip(n_k_train, b_k_train), key=lambda x: -x[0]))[1][:q]

def idx2val(idx):
    rank = predictions.index(idx) if idx in predictions else q
    return (q - rank)**2

plot_matrix = np.vstack([[idx2val(k) for k in range(70)] for _ in range(70)])
plt.pcolor(plot_matrix, cmap='gray'); plt.show()
plt.ylabel('ground truth')
plt.xlabel('prediction')

# %%
for q in [1, 5, 10, 20]:
    print 'Top {}% Subjects: {}'.format(q, sum(n_i[:q]) / sum(n_i))
# Out:
# Top 1% Subjects: 0.399319193506
# Top 5% Subjects: 0.545299816706
# Top 10% Subjects: 0.62385441215
# Top 20% Subjects: 0.724535218644

# %%
for q in [1, 5, 10, 20]:
    print 'Top {}% Objects: {}'.format(q, sum(n_j[:q]) / sum(n_i))
# Out:
# Top 1% Objects: 0.153574234093
# Top 5% Objects: 0.351008117308
# Top 10% Objects: 0.486122021472
# Top 20% Objects: 0.6459806232

# %%
for q in [1, 5, 10, 20]:
    print 'Top {}% Predicates: {}'.format(q, sum(n_k[:q]) / sum(n_i))
# Out:
# Top 1% Predicates: 0.18133019115
# Top 5% Predicates: 0.563236449332
# Top 10% Predicates: 0.806231997905
# Top 20% Predicates: 0.941345902069

# %%
# %qtconsole

# %%
def rel2word(R):
    i,j,k = R
    return idx2word['obj'][i] + '  ' + idx2word['rel'][k].replace(' ','-') + '  ' + idx2word['obj'][j]

# %%
for s in [rel2word(r) for r in R_test[:20]]:
    print s
# Out:
# person  wear  shirt
# person  wear  watch
# person  wear  shorts
# person  on  grass
# person  stand-on  grass
# person  in-the-front-of  person
# person  in-the-front-of  tree
# person  next-to  car
# person  wear  shirt
# car  behind  tree
# car  behind  person
# tree  in-the-front-of  car
# tree  behind  person
# person  wear  shirt
# person  wear  shirt
# person  stand-next-to  basket
# shirt  on  person
# tree  in  pot
# tree  next-to  cup
# pot  next-to  cup
